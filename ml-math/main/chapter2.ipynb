# %% [markdown]
# # 第二章 学习回归基于广告费预测点击量

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# ## 2.2 定义模型
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.3 最小二乘法
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 训练数据和函数的误差之和，称为`目标函数`
#
# ![image.png](attachment:image.png)
#
# > `E`代表的是误差`Error`
#
# 目标是寻找`theta`，使得`E`最小，称为`最小二乘法`

# %% [markdown]
# ### 2.3.1 最速下降法
#
# > 微分参考 [附录: 微分](./differential.ipynb)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 偏微分参考 [附录：偏微分](./partial_differentiation.ipynb)

# %% [markdown]
# ---
#
# ## 2.4 多项式回归

# %% [markdown]
# ---
#
# ## 2.5 随机梯度下降法
